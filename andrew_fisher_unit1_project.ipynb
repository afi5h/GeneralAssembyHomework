# %%
### Challenge 1: Largest Palindrome

'''A palindromic number reads the same both ways. For example, 1234321 is a palindrome. The largest palindrome made from the product of two two-digit numbers is 9009 = 91 × 99. Find the largest palindrome made from the product of two three-digit numbers. Afterward, write a brief explanation walking through your code's logic in markdown.'''

import pandas as pd
import numpy as np

# Create two lists with all possible 3-digit numbers (100 to 999)
list_a = range(100,1000)

list_b = list_a

# Use nested loops to multiply each possible combination
list_merge = []
for item_a in list_a:
    for item_b in list_b:
            multiplication_product = item_a * item_b
            list_merge.append(multiplication_product)
            
# Now create new list with only palindrome values 
list_palindrome = []
for item in list_merge:
    if str(item) == str(item)[::-1]:
           list_palindrome.append(item)
    else:
           pass

max(list_palindrome)
# 906,609 is the largest palindrome using two, three-digit numbers







### Challenge 2: Summation of Primes
'''The sum of the primes below 10 is 2 + 3 + 5 + 7 = 17. Find the sum of all the primes below 2,000. Afterward, write a brief explanation walking through your code's logic in markdown.'''

# Create list with all numbers below 2,000 (2 to 1,999, we omit 1 since cannot be prime)
list_a = range(2,2000)

# Identify all the nonprime numbers
list_nonprime = []
for items in list_a:
    numrange = range(2,items)
    for numbers in numrange:
        if items % numbers == 0:
            list_nonprime.append(items)
        else:
            pass

#Dedup the nonprime list
list_nonprime_final = []
for items in list_nonprime:
    if items not in list_nonprime_final:
        list_nonprime_final.append(items)
    else:
        pass   
    
#Now remove nonprimes from the full list
prime_counter = 0
list_prime_final = []
for items in list_a:
    if items not in list_nonprime_final:
        list_prime_final.append(items)
        prime_counter = prime_counter + items
    else:
        pass
        
#Printout final result
print(prime_counter)








### Challenge 3: Multiples of 3 and 5
'''If we list all of the natural numbers below 10 that are multiples of 3 or 5, we get 3, 5, 6, and 9. The sum of these multiples is 23. Find the sum of all the multiples of 3 or 5 below 1,000. Afterward, write a brief explanation walking through your code's logic in markdown.'''

#Create list of all numbers between 1 and 999
list_a = range(1,1000)

#Identfy all the numbers that are multiples of three (will have dividend of zero)
list_multiple_three = []
for items in list_a:
    if items % 3 == 0:
        list_multiple_three.append(items)
    else:
        pass
    
#Identfy all the numbers that are multiples of five (will have dividend of zero)
list_multiple_five = []
for items in list_a:
    if items % 5 == 0:
        list_multiple_five.append(items)
    else:
        pass
    
#Now append the two lists together and REMOVE DUPLICATES
list_multiple = list_multiple_three
for items in list_multiple_five:
    if items not in list_multiple:
        list_multiple.append(items)
    else:
        pass

#Create counter sum
counter_sum = 0
for items in list_multiple:
    counter_sum = counter_sum + items
    
#Print out answer
print(counter_sum)












### Challenge 4: String Compressor
'''Implement a method to perform basic string compression using the counts of repeated characters. (This is called run-length encoding.) For example, the string "aabcccccaaa" would become a2b1c5a3. If the “compressed” string would not become smaller than the original string, your method should return the original string. You can assume the string has only uppercase and lowercase letters (a–z). Specify whether your solution is case sensitive or case insensitive and what you would need to change to make it the other. Afterward, write a brief explanation walking through your code's logic in markdown.'''



input_string = 'aabcccccaaa'

#Determine string length to prevent loop from failing 
string_length = len(input_string)
    
#Create index position so always able to reference forward strings
index_position = 0

#Create string counter to count instances of each string
string_counter = 1

#Iterate the first string
base_string = input_string[ index_position ]

#Run loop, staying in range, looking for matches
for strings in input_string:
    
    #Use IF counter to prevent loop from getting out of range    
    if index_position < (string_length-1):
    
        #If next position matches current position, add to the counter, go back to loop
        if input_string[ index_position ] == input_string[ index_position + 1]:
            string_counter += 1
            
        #If next position does not match, grab the counter, then grab the next string    
        else:
            base_string += str(string_counter)
            string_counter = 1
            base_string += input_string[ index_position + 1]
            
    #Each loop pass needs to push index up one place
    index_position += 1
    
    #Grab last counter, since if last two strings match, counter won't be pulled in above logic
    if index_position == string_length - 1 and string_counter > 1:
        base_string += str(string_counter)
    
#Printout results
    base_string
    







### Challenge 5: FizzBuzz

'''Write a program that prints all of the numbers from 1 to 100. For multiples of 3, instead of the number, print "Fizz;" for multiples of 5, print "Buzz." For numbers that are multiples of both 3 and 5, print "FizzBuzz." Afterward, write a brief explanation walking through your code's logic in markdown.'''

for numbers in range(1,101):
    if numbers % 3 == 0 and numbers % 5 == 0:
        print("FizzBuzz")
    elif numbers % 3 == 0:
        print('Fizz')
    elif numbers % 5 == 0:
        print('Buzz')
    else:
        print(numbers)
            
#Using a loop and a series of if statements, can test for all possible conditions.
#First test for the combination multiple of 3 and 5 (since the most specific).
#Any number that fails the 3 and 5 multiple test is then sent to the 3 multiple test.
#From there, testing for multiples of 5.
#Failured of all three tests means the number is not a multiple of 3 or 5, so print the number.
# Out:
# 277050
